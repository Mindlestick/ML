# %%
import pandas as pd

x=pd.read_csv("/content/x_train.csv")
y=pd.read_csv("/content/y_train.csv")
x_test=pd.read_csv("/content/x_test.csv")
sub =pd.read_csv("/content/sample_submission.csv")

del x['date']
del y['date']
del x_test['date']

# %%
import xgboost

model = xgboost.XGBRegressor(max_depth=2, n_estimators=1010,learning_rate=0.085)
model.fit(x,y)
pred = model.predict(x_test)
pred
# Out:
# [07:05:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# array([3400.5796 , 3360.843  , 2977.4177 , 1720.2369 , 1606.9564 ,
#        1942.6827 , 2442.9614 , 3500.5498 , 2685.4834 , 2867.2078 ,
#        1953.3427 , 1145.7487 , 2481.7732 , 2700.9182 , 2410.012  ,
#        2380.8582 , 2414.8582 ,  986.38635,  906.313  , 2183.1655 ,
#        2395.688  , 2497.6611 , 2224.4863 , 2343.0918 ,  946.5244 ,
#         786.86584, 1263.3419 , 1862.6771 , 1571.6959 , 1401.6368 ,
#        1511.0073 ,  951.4854 , 1128.4932 , 1957.7712 , 1370.455  ,
#        1321.893  ,  924.5669 , 1065.2563 ,  667.07996], dtype=float32)

# %%
sub['new_deaths'] = pred
sub.to_csv('sub.csv',index=False)
